# %% [markdown]
# # Dependency preparation

# %%
# %pip install beautifulsoup
# %pip install pandas
# %pip install html5lib
# %pip install lxml
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       Traceback (most recent call last):
#         File "c:\Users\fill2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "c:\Users\fill2\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# # Data Preparation

# %%
from bs4 import BeautifulSoup
import pandas as pd

import requests

# %%
# Data source comes from Myhora

URL = "https://www.myhora.com/%E0%B8%AB%E0%B8%A7%E0%B8%A2/%E0%B8%AA%E0%B8%96%E0%B8%B4%E0%B8%95%E0%B8%B4%E0%B8%AB%E0%B8%A7%E0%B8%A2-%E0%B8%A2%E0%B9%89%E0%B8%AD%E0%B8%99%E0%B8%AB%E0%B8%A5%E0%B8%B1%E0%B8%87-10-%E0%B8%9B%E0%B8%B5.aspx?mode=year-range&value=30"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "lxml")

# %%
data_list = soup.find(id="dl_lottery_stats_list")

# %%
table = data_list.find_all('tr')

# %%
df = pd.read_html(str(data_list))[0]

df_split = df[0].str.split(' ', expand=True)
drop_columns = [0,2,4,9,14,15,16,17,18,19]
filtered_df = df_split.drop(columns=drop_columns)

filtered_df.columns = ["month", "year", "รางวัลที่ 1", "2 ตัวบน", "3 ตัวบน", "2 ตัวล่าง", "3 ตัวหน้า 1", "3 ตัวหน้า 2", "3 ตัวล่าง 1", "3 ตัวล่าง 2"]

display(filtered_df)
# Out:
# C:\Users\fill2\AppData\Local\Temp\ipykernel_37232\2299730183.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(data_list))[0]
#           month  year รางวัลที่ 1 2 ตัวบน 3 ตัวบน 2 ตัวล่าง 3 ตัวหน้า 1  \
# 0        เมษายน  2567      943598      98     598        79         727
# 1        เมษายน  2567      803481      81     481        90         122
# 2        มีนาคม  2567      997626      26     626        78         509
# 3        มีนาคม  2567      253603      03     603        79         900
# 4    กุมภาพันธ์  2567      941395      95     395        43         056
# ..          ...   ...         ...     ...     ...       ...         ...
# 715     พฤษภาคม  2537     2071764      64     764        29         093
# 716     พฤษภาคม  2537     3072877      77     877        69         535
# ...

# %% [markdown]
# # Save data to CSV file

# %%
filtered_df.to_csv('./thai-lottery-statistics-30-years.csv')
